# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import math
import operator

# %%
images = np.load("processed_data/test/images.npy", mmap_mode="r")
features = np.load("processed_data/test/features.npy", mmap_mode="r")

# %%
def distance(feature1, feature2):
    d = feature1 - feature2
    d2 = d * d
    return math.sqrt(d2.sum())

distance(np.array([1,2,1]), np.array([1,3,1]))
# Out:
# [(3, 4), (4, 3), (1, 2), (2, 1), (0, 0)]

# %%
test_index = 1

siminarity_map = {}
for i in range(len(features)):
    if not t == test_index:
        siminarity_map[i] = distance(features[test_index], features[i])
        
sims = sorted(siminarity_map.items(), key=operator.itemgetter(1), reverse=True)

# %%
plt.imshow(images[5])
plt.show()
